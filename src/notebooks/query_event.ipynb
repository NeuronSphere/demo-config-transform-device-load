# %%
# %pip install hmd-lib-notebook-magics
# Out:
# Looking in indexes: https://pypi.org/simple, https://alex.burgoon%40hmdlabs.io:****@hmdlabs.jfrog.io/artifactory/api/pypi/hmd_pypi/simple
# Requirement already satisfied: hmd-lib-notebook-magics in /opt/conda/lib/python3.9/site-packages (0.1.6)
# Requirement already satisfied: hmd-graphql-client~=0.1.84 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.84)
# Requirement already satisfied: prompt-toolkit==3.0.30 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.0.30)
# Requirement already satisfied: attrs==21.4.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (21.4.0)
# Requirement already satisfied: sqlalchemy==1.4.31 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.4.31)
# Requirement already satisfied: prettytable==0.7.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.7.2)
# Requirement already satisfied: multidict==6.0.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (6.0.2)
# Requirement already satisfied: hmd-meta-types~=0.2.84 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.85)
# Requirement already satisfied: pexpect==4.8.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (4.8.0)
# Requirement already satisfied: pyasn1==0.4.8 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.4.8)
# Requirement already satisfied: hmd-lib-naming~=0.2.22 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.22)
# Requirement already satisfied: asttokens==2.0.5 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.0.5)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.16.0)
# Requirement already satisfied: ecdsa==0.17.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.17.0)
# Requirement already satisfied: urllib3==1.26.8 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.26.8)
# Requirement already satisfied: hmd-lib-auth~=0.1.52 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.54)
# Requirement already satisfied: stack-data==0.3.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.3.0)
# Requirement already satisfied: python-jose==3.3.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.3.0)
# Requirement already satisfied: retry==0.9.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.9.2)
# Requirement already satisfied: aenum==2.2.6 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.2.6)
# Requirement already satisfied: ipython-sql==0.4.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.4.1)
# Requirement already satisfied: backcall==0.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.0)
# Requirement already satisfied: okta-jwt-verifier==0.2.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.3)
# Requirement already satisfied: requests==2.27.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.27.1)
# Requirement already satisfied: executing==0.8.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.8.3)
# Requirement already satisfied: gremlinpython==3.5.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.5.2)
# Requirement already satisfied: mako==1.1.6 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.1.6)
# Requirement already satisfied: aws-requests-auth==0.4.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.4.3)
# Requirement already satisfied: async-timeout==4.0.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (4.0.2)
# Requirement already satisfied: hmd-cli-tools~=0.2.192 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.194)
# Requirement already satisfied: isodate==0.6.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.6.1)
# Requirement already satisfied: boto3==1.21.7 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.21.7)
# Requirement already satisfied: pyyaml==6.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (6.0)
# Requirement already satisfied: hmd-lang-naming~=0.1.12 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.12)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.5)
# Requirement already satisfied: aws-secretsmanager-caching==1.1.1.5 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.1.1.5)
# Requirement already satisfied: idna==3.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.3)
# Requirement already satisfied: alembic==1.7.6 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.7.6)
# Requirement already satisfied: sqlparse==0.4.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.4.2)
# Requirement already satisfied: pyrsistent==0.18.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.18.1)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.7.5)
# Requirement already satisfied: hmd-lang-deployment~=0.1.60 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.60)
# Requirement already satisfied: backoff==1.11.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.11.1)
# Requirement already satisfied: markupsafe==2.1.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.1.0)
# Requirement already satisfied: nest-asyncio==1.5.4 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.5.4)
# Requirement already satisfied: traitlets==5.3.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (5.3.0)
# Requirement already satisfied: termcolor==1.1.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.1.0)
# Requirement already satisfied: aiohttp==3.8.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.8.1)
# Requirement already satisfied: charset-normalizer==2.0.12 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.0.12)
# Requirement already satisfied: hmd-ms-cluster~=0.1.62 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.68)
# Requirement already satisfied: jsonschema==4.4.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (4.4.0)
# Requirement already satisfied: greenlet==1.1.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.1.2)
# Requirement already satisfied: frozenlist==1.3.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.3.0)
# Requirement already satisfied: pygments==2.12.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.12.0)
# Requirement already satisfied: decorator==5.1.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (5.1.1)
# Requirement already satisfied: psycopg2-binary==2.9.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.9.3)
# Requirement already satisfied: cement==3.0.6 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (3.0.6)
# Requirement already satisfied: botocore==1.24.9 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.24.9)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.3)
# Requirement already satisfied: hmd-schema-loader~=0.2.35 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.35)
# Requirement already satisfied: parso==0.8.3 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.8.3)
# Requirement already satisfied: hmd-lang-cluster~=0.1.8 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.8)
# Requirement already satisfied: yaspin==2.1.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.1.0)
# Requirement already satisfied: yarl==1.7.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.7.2)
# Requirement already satisfied: certifi==2021.10.8 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2021.10.8)
# Requirement already satisfied: acachecontrol==0.3.5 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.3.5)
# Requirement already satisfied: python-dotenv==0.19.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.19.2)
# Requirement already satisfied: hmd-entity-storage~=0.1.198 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.1.198)
# Requirement already satisfied: jmespath==0.10.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.10.0)
# Requirement already satisfied: pure-eval==0.2.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.2)
# Requirement already satisfied: ipython==8.4.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (8.4.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.7.0)
# Requirement already satisfied: rsa==4.8 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (4.8)
# Requirement already satisfied: aiosignal==1.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.2.0)
# Requirement already satisfied: py==1.11.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (1.11.0)
# Requirement already satisfied: jedi==0.18.1 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.18.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (2.8.2)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.2.0)
# Requirement already satisfied: s3transfer==0.5.2 in /opt/conda/lib/python3.9/site-packages (from hmd-lib-notebook-magics) (0.5.2)
# Requirement already satisfied: setuptools>=38.0 in /opt/conda/lib/python3.9/site-packages (from acachecontrol==0.3.5->hmd-lib-notebook-magics) (62.3.2)
# Requirement already satisfied: websocket-client==1.3.3 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (1.3.3)
# Requirement already satisfied: cachetools==5.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (5.2.0)
# Requirement already satisfied: google-auth==2.9.1 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (2.9.1)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (0.2.8)
# Requirement already satisfied: oauthlib==3.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (3.2.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (1.3.1)
# Requirement already satisfied: kubernetes==24.2.0 in /opt/conda/lib/python3.9/site-packages (from hmd-cli-tools~=0.2.192->hmd-lib-notebook-magics) (24.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import hmd_lib_notebook_magics.cluster_management
# %load_ext hmd_lib_notebook_magics.cluster_management

# %%
cluster_conn = 'trino://trino-clst-spot:trino-1/hive?protocol=https'
local_trino = 'trino://admin@trino:8081/hive'

# Need for Trino databases
# %config NSClusterMagics.autocommit=False

# the local override must come first
# %local_cluster_override {cluster_conn} {local_trino}
# %nscluster {cluster_conn}
# Out:
# trino://admin@trino:8081/hive
# Using local override: trino://admin@trino:8081/hive

# %%
# %%sql
# SELECT COUNT()
# FROM demo_final.telemetry
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [(10000,)]

# %%
# %%sql
# SELECT *, "event_detail.code"-1 FROM demo_final.event WHERE "event_detail.code" = 200 LIMIT 10
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# []

# %%
# %%sql
# SHOW SCHEMAS

# %%
# %%sql
# DROP TABLE IF EXISTS demo_staging.telemetry
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [(True,)]

# %%
# %%sql
# create table if not exists demo_source.event (
#     "timestamp" timestamp,
#     "type" varchar,
#     "detail" ROW ("code" int, "message" varchar)
# ) with (
#     external_location = 'file:///hmd/data/raw/',
#     format = 'JSON'
# )
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [(True,)]

# %%
# %%sql
# SHOW SCHEMAS
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [('default',),
#  ('demo',),
#  ('demo_final',),
#  ('demo_source',),
#  ('demo_staging',),
#  ('demo_ux',),
#  ('information_schema',),
#  ('sample',)]

# %%
# %%sql
# DROP SCHEMA demo_staging
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [(True,)]

# %%
# %%sql
# DELETE FROM demo_staging.event
# Out:
#  * trino://admin@trino:8081/hive
# Done.
# [(None,)]
